# %%
import pandas as pd

pd.read_csv('usfk_holiday_schedule_2024_v3.csv')
# Out:
#          Date        Day                                       Holiday US ROK  \
# 0    2-Oct-23     Monday  Chuseok (ROK)/National Foundation Bridge Day     NO
# 1    3-Oct-23    Tuesday                 National Foundation Day (ROK)     NO
# 2    9-Oct-23     Monday            Hangul (Korean Language) Day (ROK)     NO
# 3    9-Oct-23     Monday                             Columbus Day (US)    YES
# 4   10-Nov-23     Friday          Training Holiday (US) - Veterans Day    YES
# 5   10-Nov-23     Friday                    Veterans Day (US) Observed    YES
# 6   24-Nov-23     Friday          Korean Employee Union Foundation Day     NO
# 7   23-Nov-23   Thursday                         Thanksgiving Day (US)    YES
# 8   24-Nov-23     Friday            Thanksgiving Training Holiday (US)    YES
# 9   25-Dec-23     Monday                        Christmas Day (US/ROK)    YES
# 10  26-Dec-23    Tuesday           Christmas Day (US) Training Holiday    YES
# ...
