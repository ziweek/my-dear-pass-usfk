# %%
import pandas as pd

df_origin = pd.read_csv('USFK 2025 Holiday Schedule (v2).csv', index_col=False)
df_origin.head()
# Out:
#         DATE        DAY                                         HOLIDAY   US  \
# 0   3-Oct-24   THURSDAY                   NATIONAL FOUNDATION DAY (ROK)   NO
# 1   4-Oct-24     FRIDAY  NATIONAL FOUNDATION DAY (ROK) TRAINING HOLIDAY   NO
# 2   9-Oct-24  WEDNESDAY              HANGUL (KOREAN LANGUAGE) DAY (ROK)   NO
# 3  11-Oct-24     FRIDAY              COLUMBUS DAY (US) TRAINING HOLIDAY  YES
# 4  14-Oct-24     MONDAY                               COLUMBUS DAY (US)  YES
#
#    ROK KATUSA DOD (US) USFK (LN)  Unnamed: 8  Unnamed: 9 CFC (KN) DODEA (US)  \
# 0  YES     NO       NO       YES         NaN         NaN      YES         NO
# 1  YES     NO       NO        NO         NaN         NaN       NO         NO
# 2  YES     NO       NO       YES         NaN         NaN      YES         NO
# 3   NO    YES       NO        NO         NaN         NaN       NO     RECESS
# 4   NO    YES      YES        NO         NaN         NaN       NO        YES
#
#    Unnamed: 12
# 0          NaN
# ...

# %%
df_origin.to_json('fy24_usfk_holiday_v2.json', orient='records')
